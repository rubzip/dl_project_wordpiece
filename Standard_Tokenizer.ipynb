# %% [markdown]
# # Experiment: Standart Tokenizer vs BytePairEncoding

# %% [markdown]
# ### Standard Tokenizer

# %%
from Tokenizer import Tokenizer, load_sst_data, word_freq_dictionary, tokenize, clean

# %%
dim = 5000

# %%
# Loading datasets
dataset = dict()
for data in ('train', 'test', 'dev'):
    dataset[data] = load_sst_data(f"./data/{data}.txt")

# %%
word_freq = word_freq_dictionary(dataset['train'], sep='')
word_freq.head()
# Out:
#    word  freq
# 4   the  5954
# 26    a  4361
# 14  and  3831
# 46   of  3631
# 18   to  2438

# %%
tokenizer = Tokenizer(dim)
tokenizer.train(word_freq)

# %%
words = [
     'lessons',
     'stilted',
     'bond',
     'relentlessly',
     'caper',
     'dysfunctional',
     'multiplex',
     'pleasant',
     'asaaaa'
        ]

for word in words:
    code = tokenizer.encode(word)
    n_word = tokenizer.decode(code)
    print(word, code, n_word)
# Out:
# lessons 2526 lessons
# stilted 4189 stilted
# bond 468 bond
# relentlessly 3544 relentlessly
# caper 591 caper
# dysfunctional 1299 dysfunctional
# multiplex 2868 multiplex
# pleasant 3241 pleasant
# asaaaa 0 <UNK>

# %%
dataset['train']
# Out:
# [{'label': 0,
#   'text': 'Yet another entry in the sentimental oh-those-wacky-Brits genre that was ushered in by The Full Monty and is still straining to produce another smash hit .'},
#  {'label': 0,
#   'text': 'It desperately wants to be a wacky , screwball comedy , but the most screwy thing here is how so many talented people were convinced to waste their time .'},
#  {'label': 1,
#   'text': 'A bit of a downer and a little over-dramatic at times , but this is a beautiful film for people who like their romances to have that French realism .'},
#  {'label': 0, 'text': "It 's horribly depressing and not very well done ."},
#  {'label': 1,
#   'text': 'In painting an unabashedly romantic picture of a nation whose songs spring directly from the lives of the people , the movie exalts the Marxian dream of honest working folk , with little to show for their labor , living harmoniously , joined in song .'},
#  {'label': 1,
#   'text': "A plethora of engaging diatribes on the meaning of ` home , ' delivered in grand passion by the members of the various households ."},
#  {'label': 1,
#   'text': 'Like a veteran head cutter , Barbershop is tuned in to its community .'},
#  {'label': 0,
#   'text': "Unfortunately , that 's precisely what Arthur Dong 's Family Fundamentals does ."},
#  {'label': 1,
#   'text': 'A breathtaking adventure for all ages , Spirit tells its poignant and uplifting story in a stunning fusion of music and images .'},
#  {'label': 0,
#   'text': "The overall feel is not unlike watching a glorified episode of `` 7th Heaven . ''"},
#  {'label': 0,
#   'text': "While some of the camera work is interesting , the film 's mid-to-low budget is betrayed by the surprisingly shoddy makeup work ."},
#  {'label': 0,
#   'text': 'As a feature-length film , it wears out its welcome as tryingly as the title character .'},
#  {'label': 1,
#   'text': 'The more you think about the movie , the more you will probably like it .'},
#  {'label': 1,
#   'text': 'Director Claude Chabrol has become the master of innuendo .'},
#  {'label': 1,
#   'text': 'Tres Greek writer and star Nia Vardalos has crafted here a worldly-wise and very funny script .'},
#  {'label': 0, 'text': 'Kitschy , flashy , overlong soap opera .'},
#  {'label': 1,
#   'text': 'Davis ... gets vivid performances from her cast and pulls off some deft Ally McBeal-style fantasy sequences .'},
#  {'label': 0,
#   'text': 'Purports to be a Hollywood satire but winds up as the kind of film that should be the target of something deeper and more engaging .'},
#  {'label': 1,
#   'text': 'As the dominant Christine , Sylvie Testud is icily brilliant .'},
#  {'label': 1,
#   'text': "It 's nice to see Piscopo again after all these years , and Chaykin and Headly are priceless ."},
#  {'label': 0,
#   'text': "When a movie asks you to feel sorry for Mick Jagger 's sex life , it already has one strike against it ."},
#  {'label': 1,
#   'text': "Quaid is utterly fearless as the tortured husband living a painful lie , and Moore wonderfully underplays the long-suffering heroine with an unflappable '50s dignity somewhere between Jane Wyman and June Cleaver ."},
#  {'label': 0, 'text': "It 's quite diverting nonsense ."},
#  {'label': 0,
#   'text': "Should n't have been allowed to use the word `` new '' in its title , because there 's not an original character , siuation or joke in the entire movie ."},
#  {'label': 1,
#   'text': 'Not many movies have that kind of impact on me these days .'},
#  {'label': 0,
#   'text': "` Punch-Drunk Love is so convinced of its own brilliance that , if it were a person , you 'd want to smash its face in . '"},
#  {'label': 1,
#   'text': 'Though its rather routine script is loaded with familiar situations , the movie has a cinematic fluidity and sense of intelligence that makes it work more than it probably should .'},
#  {'label': 0,
#   'text': "There 's not a single jump-in-your-seat moment and believe it or not , Jason actually takes a backseat in his own film to special effects ."},
#  {'label': 1,
#   'text': "Canadian filmmaker Gary Burns ' inventive and mordantly humorous take on the soullessness of work in the city ."},
#  {'label': 0,
#   'text': 'Feels like pieces a bunch of other , better movies slapped together .'},
#  {'label': 0,
#   'text': 'With tiny little jokes and nary an original idea , this sappy ethnic sleeper proves that not only blockbusters pollute the summer movie pool .'},
#  {'label': 1,
#   'text': 'Although devoid of objectivity and full of nostalgic comments from the now middle-aged participants , Dogtown and Z-Boys has a compelling story to tell .'},
#  {'label': 0, 'text': '... one resurrection too many .'},
#  {'label': 0,
#   'text': 'Hill looks to be going through the motions , beginning with the pale script .'},
#  {'label': 1, 'text': "`` Extreme Ops '' exceeds expectations ."},
#  {'label': 1,
#   'text': 'Its metaphors are opaque enough to avoid didacticism , and the film succeeds as an emotionally accessible , almost mystical work .'},
#  {'label': 1, 'text': "A stylistic romp that 's always fun to watch ."},
#  {'label': 1,
#   'text': 'Even with all its botches , Enigma offers all the pleasure of a handsome and well-made entertainment .'},
#  {'label': 1,
#   'text': 'Each of these stories has the potential for Touched by an Angel simplicity and sappiness , but Thirteen Conversations About One Thing , for all its generosity and optimism , never resorts to easy feel-good sentiments .'},
#  {'label': 0,
#   'text': 'Then again , in a better movie , you might not have noticed .'},
#  {'label': 0,
#   'text': 'Cuba Gooding Jr. valiantly mugs his way through Snow Dogs , but even his boisterous energy fails to spark this leaden comedy .'},
#  {'label': 1, 'text': 'Morton deserves an Oscar nomination .'},
#  {'label': 0,
#   'text': "Cheap , vulgar dialogue and a plot that crawls along at a snail 's pace ."},
#  {'label': 1,
#   'text': 'Horrid little propaganda film with fascinating connections not only to the Serbs themselves but also to a network of American right-wing extremists .'},
#  {'label': 0,
#   'text': '-LRB- Evans is -RRB- a fascinating character , and deserves a better vehicle than this facetious smirk of a movie .'},
#  {'label': 0,
#   'text': 'To the vast majority of more casual filmgoers , it will probably be a talky bore .'},
#  {'label': 1,
#   'text': "I 've yet to find an actual Vietnam War combat movie actually produced by either the North or South Vietnamese , but at least now we 've got something pretty damn close ."},
#  {'label': 1,
#   'text': 'For once , a movie does not proclaim the truth about two love-struck somebodies , but permits them time and space to convince us of that all on their own .'},
#  {'label': 1, 'text': 'All three women deliver remarkable performances .'},
#  {'label': 1, 'text': 'Fun and nimble .'},
#  {'label': 0,
#   'text': "Tartakovsky 's team has some freakish powers of visual charm , but the five writers slip into the modern rut of narrative banality ."},
#  {'label': 0,
#   'text': 'A particularly joyless , and exceedingly dull , period coming-of-age tale .'},
#  {'label': 1,
#   'text': 'A thoroughly engaging , surprisingly touching British comedy .'},
#  {'label': 1,
#   'text': 'Even through its flaws , Revolution # 9 proves to be a compelling , interestingly told film .'},
#  {'label': 0, 'text': "It 's not original enough ."},
#  {'label': 1,
#   'text': "Far From Heaven is a dazzling conceptual feat , but more than that , it 's a work of enthralling drama ."},
#  {'label': 1,
#   'text': "Argento , at only 26 , brings a youthful , out-to-change-the-world aggressiveness to the project , as if she 's cut open a vein and bled the raw film stock ."},
#  {'label': 0,
#   'text': 'Nearly all the fundamentals you take for granted in most films are mishandled here .'},
#  {'label': 0,
#   'text': 'An unremittingly ugly movie to look at , listen to , and think about , it is quite possibly the sturdiest example yet of why the DV revolution has cheapened the artistry of making a film .'},
#  {'label': 1,
#   'text': "The movie 's captivating details are all in the performances , from Foreman 's barking-mad Taylor to Thewlis 's smoothly sinister Freddie and Bettany\\/McDowell 's hard-eyed gangster ."},
#  {'label': 1,
#   'text': 'If you like an extreme action-packed film with a hint of humor , then Triple X marks the spot .'},
#  {'label': 0,
#   'text': "No amount of nostalgia for Carvey 's glory days can disguise the fact that the new film is a lame kiddie flick and that Carvey 's considerable talents are wasted in it ."},
#  {'label': 0,
#   'text': 'plays like some corny television production from a bygone era'},
#  {'label': 1,
#   'text': 'As played by Ryan Gosling , Danny is a frighteningly fascinating contradiction .'},
#  {'label': 0, 'text': 'It has no affect on the Kurds , but it wore me down .'},
#  {'label': 0,
#   'text': "Hart 's War seems to want to be a character study , but apparently ca n't quite decide which character ."},
#  {'label': 1,
#   'text': "But it 's defiantly and delightfully against the grain ."},
#  {'label': 1, 'text': 'It deserves to be seen everywhere .'},
#  {'label': 0,
#   'text': 'Once he starts learning to compromise with reality enough to become comparatively sane and healthy , the film becomes predictably conventional .'},
#  {'label': 0,
#   'text': 'McKay seems embarrassed by his own invention and tries to rush through the intermediary passages , apparently hoping that the audience will not notice the glaring triteness of the plot device he has put in service .'},
#  {'label': 0,
#   'text': "With the cheesiest monsters this side of a horror spoof , which They is n't , it is more likely to induce sleep than fright ."},
#  {'label': 1,
#   'text': "The gentle comic treatment of adolescent sturm und drang should please fans of Chris Fuhrman 's posthumously published cult novel ."},
#  {'label': 1,
#   'text': 'A tour de force drama about the astonishingly pivotal role of imagination in the soulful development of two rowdy teenagers .'},
#  {'label': 0, 'text': "Murder by Numbers just does n't add up ."},
#  {'label': 1,
#   'text': 'It is about irrational , unexplainable life and it seems so real because it does not attempt to filter out the complexity .'},
#  {'label': 1,
#   'text': "By and large this is Mr. Kilmer 's movie , and it 's his strongest performance since The Doors ."},
#  {'label': 1, 'text': 'I like this movie a lot .'},
#  {'label': 0, 'text': 'Perhaps the grossest movie ever made .'},
#  {'label': 0,
#   'text': "It 's not so much a movie as a joint promotion for the National Basketball Association and teenaged rap and adolescent poster-boy Lil ' Bow Wow ."},
#  {'label': 1,
#   'text': 'This is a visually stunning rumination on love , memory , history and the war between art and commerce .'},
#  {'label': 0,
#   'text': "I 'm not sure which is worse : the poor acting by the ensemble cast , the flat dialogue by Vincent R. Nebrida or the gutless direction by Laurice Guillen ."},
#  {'label': 0,
#   'text': "To some eyes this will seem like a recycling of clichÃ©s , an assassin 's greatest hits ."},
#  {'label': 1,
#   'text': 'There are no special effects , and no Hollywood endings .'},
#  {'label': 1,
#   'text': 'An old-fashioned but emotionally stirring adventure tale of the kind they rarely make anymore .'},
#  {'label': 1,
#   'text': 'For more than two decades Mr. Nachtwey has traveled to places in the world devastated by war , famine and poverty and documented the cruelty and suffering he has found with an devastating , eloquent clarity .'},
#  {'label': 0,
#   'text': 'The only reason you should see this movie is if you have a case of masochism and an hour and a half to blow .'},
#  {'label': 1,
#   'text': "Ong 's promising debut is a warm and well-told tale of one recent Chinese immigrant 's experiences in New York City ."},
#  {'label': 0,
#   'text': "Whatever satire Lucky Break was aiming for , it certainly got lost in the `` soon-to-be-forgettable '' section of the quirky rip-off prison romp pile ."},
#  {'label': 0, 'text': 'Halfway through the movie , the humor dwindles .'},
#  {'label': 0,
#   'text': 'a huge disappointment coming , as it does , from filmmakers and performers of this calibre'},
#  {'label': 1, 'text': 'Leigh makes these lives count .'},
#  {'label': 0,
#   'text': "It 's unfortunate that Wallace , who wrote Gibson 's Braveheart as well as the recent Pearl Harbor , has such an irrepressible passion for sappy situations and dialogue ."},
#  {'label': 1,
#   'text': 'You walk out of The Good Girl with mixed emotions -- disapproval of Justine combined with a tinge of understanding for her actions .'},
#  {'label': 0,
#   'text': 'A sloppy slapstick throwback to long gone bottom-of-the-bill fare like The Ghost and Mr. Chicken .'},
#  {'label': 1,
#   'text': "It 's enough to watch Huppert scheming , with her small , intelligent eyes as steady as any noir villain , and to enjoy the perfectly pitched web of tension that Chabrol spins ."},
#  {'label': 1,
#   'text': 'There are so few films about the plight of American Indians in modern America that Skins comes as a welcome , if downbeat , missive from a forgotten front .'},
#  {'label': 0, 'text': 'Unwieldy contraption .'},
#  {'label': 0,
#   'text': "This New Zealand coming-of-age movie is n't really about anything ."},
#  {'label': 1,
#   'text': "Judith and Zaza 's extended bedroom sequence ... is so intimate and sensual and funny and psychologically self-revealing that it makes most of what passes for sex in the movies look like cheap hysterics ."},
#  {'label': 0,
#   'text': "There 's some good material in their story about a retail clerk wanting more out of life , but the movie too often spins its wheels with familiar situations and repetitive scenes ."},
#  {'label': 1,
#   'text': 'What makes Barbershop so likable , with all its flaws , is that it has none of the pushiness and decibel volume of most contemporary comedies .'},
#  {'label': 1,
#   'text': 'Nicks sustains the level of exaggerated , stylized humor throughout by taking your expectations and twisting them just a bit .'},
#  {'label': 1, 'text': '... a solid , unassuming drama .'},
#  {'label': 1,
#   'text': "Waiting for Godard can be fruitful : ` In Praise of Love ' is the director 's epitaph for himself ."},
#  {'label': 1, 'text': 'But it is entertaining on an inferior level .'},
#  {'label': 0,
#   'text': "While the film is competent , it 's also uninspired , lacking the real talent and wit to elevate it beyond its formula to the level of classic romantic comedy to which it aspires ."},
#  {'label': 1, 'text': 'At times , the movie looks genuinely pretty .'},
#  {'label': 0, 'text': "Vaguely interesting , but it 's just too too much ."},
#  {'label': 0, 'text': 'Disjointed parody .'},
#  {'label': 0,
#   'text': 'In a big corner office in Hell , Satan is throwing up his hands in surrender , is firing his R&D people , and has decided he will just screen The Master of Disguise 24\\/7 .'},
#  {'label': 0,
#   'text': "With Zoe Clarke-Williams 's lackluster thriller `` New Best Friend '' , who needs enemies ?"},
#  {'label': 0, 'text': 'Leaks treacle from every pore .'},
#  {'label': 1, 'text': 'A gripping drama .'},
#  {'label': 1,
#   'text': 'Measured against practically any like-themed film other than its Oscar-sweeping franchise predecessor The Silence of the Lambs , Red Dragon rates as an exceptional thriller .'},
#  {'label': 0,
#   'text': 'The town has kind of an authentic feel , but each one of these people stand out and everybody else is in the background and it just seems manufactured to me and artificial .'},
#  {'label': 1,
#   'text': 'Alternating between facetious comic parody and pulp melodrama , this smart-aleck movie ... tosses around some intriguing questions about the difference between human and android life .'},
#  {'label': 1,
#   'text': 'Generates an enormous feeling of empathy for its characters .'},
#  {'label': 0,
#   'text': 'Big Fat Liar is little more than Home Alone raised to a new , self-deprecating level .'},
#  {'label': 0,
#   'text': "Pretend it 's a werewolf itself by avoiding eye contact and walking slowly away ."},
#  {'label': 0, 'text': 'Not so much farcical as sour .'},
#  {'label': 0,
#   'text': 'Tedious Norwegian offering which somehow snagged an Oscar nomination .'},
#  {'label': 1, 'text': "It 's definitely a step in the right direction ."},
#  {'label': 1, 'text': 'The cast delivers without sham the raw-nerved story .'},
#  {'label': 1,
#   'text': "In the affable Maid in Manhattan , Jennifer Lopez 's most aggressive and most sincere attempt to take movies by storm , the diva shrewdly surrounds herself with a company of strictly A-list players ."},
#  {'label': 0,
#   'text': 'A cellophane-pop remake of the punk classic Ladies and Gentlemen , The Fabulous Stains ... Crossroads is never much worse than bland or better than inconsequential .'},
#  {'label': 0,
#   'text': "Once the expectation of laughter has been quashed by whatever obscenity is at hand , even the funniest idea is n't funny ."},
#  {'label': 0,
#   'text': "After seeing the film , I can tell you that there 's no other reason why anyone should bother remembering it ."},
#  {'label': 1,
#   'text': '... a series of tales told with the intricate preciseness of the best short story writing .'},
#  {'label': 0,
#   'text': 'The movie barely makes sense , with its unbelievable naÃ¯vetÃ© and arbitrary flashbacks .'},
#  {'label': 1,
#   'text': "A meatier deeper beginning and\\/or ending would have easily tipped this film into the `` A '' range , as is , it 's a very very strong `` B + . ''"},
#  {'label': 1,
#   'text': "Japanese director Shohei Imamura 's latest film is an odd but ultimately satisfying blend of the sophomoric and the sublime ."},
#  {'label': 0,
#   'text': "The Paradiso 's rusted-out ruin and ultimate collapse during the film 's final -LRB- restored -RRB- third ... emotionally belittle a cinema classic ."},
#  {'label': 0,
#   'text': "` It 's painful to watch Witherspoon 's talents wasting away inside unnecessary films like Legally Blonde and Sweet Home Abomination , I mean , Alabama . '"},
#  {'label': 0,
#   'text': 'plays like an unbalanced mixture of graphic combat footage and almost saccharine domestic interludes that are pure Hollywood .'},
#  {'label': 1,
#   'text': 'Thanks to confident filmmaking and a pair of fascinating performances , the way to that destination is a really special walk in the woods .'},
#  {'label': 1,
#   'text': "But as you watch the movie , you 're too interested to care ."},
#  {'label': 0, 'text': 'A brutally dry satire of Middle American numbness .'},
#  {'label': 0,
#   'text': "If Hill is n't quite his generation 's Don Siegel -LRB- or Robert Aldrich -RRB- , it 's because there 's no discernible feeling beneath the chest hair ; it 's all bluster and clichÃ© ."},
#  {'label': 0,
#   'text': "Although it tries to be much more , it 's really just another Major League ."},
#  {'label': 0, 'text': '-LRB- A -RRB- crushing disappointment .'},
#  {'label': 1, 'text': 'The movie is so thoughtlessly assembled .'},
#  {'label': 0, 'text': 'The jokes are flat , and the action looks fake .'},
#  {'label': 0,
#   'text': 'Its message has merit and , in the hands of a brutally honest individual like Prophet Jack , might have made a point or two regarding life .'},
#  {'label': 1, 'text': 'A perfectly pleasant if slightly pokey comedy .'},
#  {'label': 0,
#   'text': "There 's a persistent theatrical sentiment and a woozy quality to the manner of the storytelling , which undercuts the devastatingly telling impact of utter loss personified in the film 's simple title ."},
#  {'label': 1,
#   'text': "With amazing finesse , the film shadows Heidi 's trip back to Vietnam and the city where her mother , Mai Thi Kim , still lives ."},
#  {'label': 0,
#   'text': "High Crimes carries almost no organic intrigue as a government \\/ Marine\\/legal mystery , and that 's because the movie serves up all of that stuff , nearly subliminally , as the old-hat province of male intrigue ."},
#  {'label': 1,
#   'text': 'But the nerve-raked acting , the crackle of lines , the impressive stagings of hardware , make for some robust and scary entertainment .'},
#  {'label': 0,
#   'text': 'Cinematic pyrotechnics aside , the only thing Avary seems to care about are mean giggles and pulchritude .'},
#  {'label': 1,
#   'text': 'Affable if not timeless , Like Mike raises some worthwhile themes while delivering a wholesome fantasy for kids .'},
#  {'label': 1,
#   'text': 'The way the roundelay of partners functions , and the interplay within partnerships and among partnerships and the general air of Gator-bashing are consistently delightful .'},
#  {'label': 1,
#   'text': 'While the humor is recognizably Plympton , he has actually bothered to construct a real story this time .'},
#  {'label': 1,
#   'text': "What 's surprising about this traditional thriller , moderately successful but not completely satisfying , is exactly how genteel and unsurprising the execution turns out to be ."},
#  {'label': 0,
#   'text': 'Borstal Boy represents the worst kind of filmmaking , the kind that pretends to be passionate and truthful but is really frustratingly timid and soggy .'},
#  {'label': 0,
#   'text': 'It appears to have been modeled on the worst revenge-of-the-nerds clichÃ©s the filmmakers could dredge up .'},
#  {'label': 1,
#   'text': 'It also shows how deeply felt emotions can draw people together across the walls that might otherwise separate them .'},
#  {'label': 1,
#   'text': "There 's absolutely no reason why Blue Crush , a late-summer surfer girl entry , should be as entertaining as it is"},
#  {'label': 1,
#   'text': 'Affirms the gifts of all involved , starting with Spielberg and going right through the ranks of the players -- on-camera and off -- that he brings together .'},
#  {'label': 1,
#   'text': 'Often shocking but ultimately worthwhile exploration of motherhood and desperate mothers .'},
#  {'label': 1,
#   'text': "The unexplored story opportunities of `` Punch-Drunk Love '' may have worked against the maker 's minimalist intent but it is an interesting exercise by talented writer\\/director Anderson ."},
#  {'label': 0,
#   'text': 'Rarely does a film so graceless and devoid of merit as this one come along .'},
#  {'label': 0,
#   'text': "None of this is very original , and it is n't particularly funny ."},
#  {'label': 0,
#   'text': "There 's a reason the studio did n't offer an advance screening ."},
#  {'label': 1,
#   'text': "The re-release of Ron Howard 's Apollo 13 in the IMAX format proves absolutely that really , really , really good things can come in enormous packages ."},
#  {'label': 1,
#   'text': "Dog Soldiers does n't transcend genre -- it embraces it , energizes it and takes big bloody chomps out of it ."},
#  {'label': 1, 'text': 'See it for his performance if nothing else .'},
#  {'label': 1, 'text': 'Smarter than its commercials make it seem .'},
#  {'label': 1,
#   'text': 'Renner carries much of the film with a creepy and dead-on performance .'},
#  {'label': 0,
#   'text': "It lacks the compassion , good-natured humor and the level of insight that made -LRB- Eyre 's -RRB- first film something of a sleeper success ."},
#  {'label': 0,
#   'text': 'This misty-eyed Southern nostalgia piece , in treading the line between sappy and sanguine , winds up mired in tear-drenched quicksand .'},
#  {'label': 0,
#   'text': "Judd 's characters ought to pick up the durable best seller Smart Women , Foolish Choices for advice ."},
#  {'label': 1,
#   'text': "One of the smarter offerings the horror genre has produced in recent memory , even if it 's far tamer than advertised ."},
#  {'label': 1, 'text': 'Exciting and well-paced .'},
#  {'label': 1,
#   'text': 'Its flame-like , roiling black-and-white inspires trembling and gratitude .'},
#  {'label': 0,
#   'text': 'This is the kind of movie during which you want to bang your head on the seat in front of you , at its cluelessness , at its idiocy , at its utterly misplaced earnestness .'},
#  {'label': 1,
#   'text': 'Two Weeks Notice has appeal beyond being a Sandra Bullock vehicle or a standard romantic comedy .'},
#  {'label': 0,
#   'text': "It 's just too bad the screenwriters eventually shoot themselves in the feet with cop flick cliches like an oily arms dealer , squad car pile-ups and the requisite screaming captain ."},
#  {'label': 1,
#   'text': 'Some of the most inventive silliness you are likely to witness in a movie theatre for some time .'},
#  {'label': 0,
#   'text': 'Terminally bland , painfully slow and needlessly confusing ... The movie , shot on digital videotape rather than film , is frequently indecipherable .'},
#  {'label': 1,
#   'text': 'Yes , MIBII is rote work and predictable , but with a philosophical visual coming right at the end that extravagantly redeems it .'},
#  {'label': 1,
#   'text': 'Chicago offers much colorful eye candy , including the spectacle of Gere in his dancing shoes , hoofing and crooning with the best of them .'},
#  {'label': 1,
#   'text': 'The mood , look and tone of the film fit the incredible storyline to a T.'},
#  {'label': 1,
#   'text': "that it 'll probably be the best and most mature comedy of the 2002 summer season speaks more of the season than the picture"},
#  {'label': 0,
#   'text': 'The script is a dim-witted pairing of teen-speak and animal gibberish .'},
#  {'label': 0,
#   'text': 'It is a popcorn film , not a must-own , or even a must-see .'},
#  {'label': 1,
#   'text': 'With the same sort of good-natured fun found in films like Tremors , Eight Legged Freaks is prime escapist fare .'},
#  {'label': 0,
#   'text': 'The innate theatrics that provide its thrills and extreme emotions lose their luster when flattened onscreen .'},
#  {'label': 0,
#   'text': 'Can I admit XXX is as deep as a Petri dish and as well-characterized as a telephone book but still say it was a guilty pleasure ?'},
#  {'label': 0,
#   'text': "The most repugnant adaptation of a classic text since Roland JoffÃ© and Demi Moore 's The Scarlet Letter ."},
#  {'label': 1,
#   'text': 'a bilingual charmer , just like the woman who inspired it'},
#  {'label': 0,
#   'text': 'Hip-hop rarely comes alive as its own fire-breathing entity in this picture .'},
#  {'label': 1,
#   'text': "Michael Moore has perfected the art of highly entertaining , self-aggrandizing , politically motivated documentary-making , and he 's got as potent a topic as ever here ."},
#  {'label': 0,
#   'text': 'In comparison to his earlier films it seems a disappointingly thin slice of lower-class London life ; despite the title ... amounts to surprisingly little .'},
#  {'label': 1,
#   'text': 'A much better documentary -- more revealing , more emotional and more surprising -- than its pedestrian English title would have you believe .'},
#  {'label': 1, 'text': 'a joyous occasion'},
#  {'label': 1,
#   'text': "It 's a square , sentimental drama that satisfies , as comfort food often can ."},
#  {'label': 0,
#   'text': "The movie is a lumbering load of hokum but ... it 's at least watchable ."},
#  {'label': 1,
#   'text': 'A dark , quirky road movie that constantly defies expectation .'},
#  {'label': 1,
#   'text': "The film 's intimate camera work and searing performances pull us deep into the girls ' confusion and pain as they struggle tragically to comprehend the chasm of knowledge that 's opened between them ."},
#  {'label': 1, 'text': "I simply ca n't recommend it enough ."},
#  {'label': 0,
#   'text': "Like being able to hit on a 15-year old when you 're over 100 ."},
#  {'label': 0,
#   'text': 'It feels like very light Errol Morris , focusing on eccentricity but failing , ultimately , to make something bigger out of its scrapbook of oddballs .'},
#  {'label': 0,
#   'text': "Instead of contriving a climactic hero 's death for the beloved-major - character-who-shall - remain-nameless , why not invite some genuine spontaneity into the film by having the evil aliens ' laser guns actually hit something for once ?"},
#  {'label': 0,
#   'text': 'One of those films that started with a great premise and then just fell apart .'},
#  {'label': 1,
#   'text': "Light the candles , bring out the cake and do n't fret about the calories because there 's precious little substance in Birthday Girl -- it 's simply , and surprisingly , a nice , light treat ."},
#  {'label': 0, 'text': "That 's because relatively nothing happens ."},
#  {'label': 0,
#   'text': 'So putrid it is not worth the price of the match that should be used to burn every print of the film .'},
#  {'label': 0,
#   'text': 'A disaster of a drama , saved only by its winged assailants .'},
#  {'label': 0, 'text': 'Low rent from frame one .'},
#  {'label': 0,
#   'text': '... contains very few laughs and even less surprises .'},
#  {'label': 1,
#   'text': 'One of the finest , most humane and important Holocaust movies ever made .'},
#  {'label': 1,
#   'text': "The wonderfully lush Morvern Callar is pure punk existentialism , and Ms. Ramsay and her co-writer , Liana Dognini , have dramatized the Alan Warner novel , which itself felt like an answer to Irvine Welsh 's book Trainspotting ."},
#  {'label': 1,
#   'text': 'Satisfyingly scarifying , fresh and old-fashioned at the same time .'},
#  {'label': 0,
#   'text': 'After all , he took three minutes of dialogue , 30 seconds of plot and turned them into a 90-minute movie that feels five hours long .'},
#  {'label': 0,
#   'text': 'Woody Allen used to ridicule movies like Hollywood Ending .'},
#  {'label': 1,
#   'text': "May take its sweet time to get wherever it 's going , but if you have the patience for it , you wo n't feel like it 's wasted yours ."},
#  {'label': 1,
#   'text': 'Wang Xiaoshuai directs this intricately structured and well-realized drama that presents a fascinating glimpse of urban life and the class warfare that embroils two young men .'},
#  {'label': 0,
#   'text': 'is significantly less charming than listening to a four-year-old with a taste for exaggeration recount his Halloween trip to the Haunted House .'},
#  {'label': 0,
#   'text': 'A tired , predictable , bordering on offensive , waste of time , money and celluloid .'},
#  {'label': 1,
#   'text': 'It makes compelling , provocative and prescient viewing .'},
#  {'label': 1,
#   'text': 'Visually fascinating ... an often intense character study about fathers and sons , loyalty and duty .'},
#  {'label': 1,
#   'text': 'Thumbs up to Paxton for not falling into the Hollywood trap and making a vanity project with nothing new to offer .'},
#  {'label': 1,
#   'text': 'This is the kind of subject matter that could so easily have been fumbled by a lesser filmmaker , but Ayres makes the right choices at every turn .'},
#  {'label': 1,
#   'text': 'The film sparkles with the the wisdom and humor of its subjects .'},
#  {'label': 1,
#   'text': "Fear permeates the whole of Stortelling , Todd Solondz ' oftentimes funny , yet ultimately cowardly autocritique ."},
#  {'label': 1,
#   'text': "`` the road paved with good intentions leads to the video store ''"},
#  {'label': 0,
#   'text': 'Contains all the substance of a Twinkie -- easy to swallow , but scarcely nourishing .'},
#  {'label': 1,
#   'text': "An entertaining documentary that freshly considers arguments the Bard 's immortal plays were written by somebody else ."},
#  {'label': 0,
#   'text': "With a `` Spy Kids '' sequel opening next week , why bother with a contemptible imitator starring a `` SNL '' has-been acting like an 8-year-old channeling Roberto Benigni ?"},
#  {'label': 0,
#   'text': 'The Good Girl is a film in which the talent is undeniable but the results are underwhelming .'},
#  {'label': 1,
#   'text': "It 's a technically superb film , shining with all the usual Spielberg flair , expertly utilizing the talents of his top-notch creative team ."},
#  {'label': 0,
#   'text': 'But mainstream audiences will find little of interest in this film , which is often preachy and poorly acted .'},
#  {'label': 1,
#   'text': 'A deft , delightful mix of sulky teen drama and overcoming-obstacles sports-movie triumph .'},
#  {'label': 0,
#   'text': 'Like the Tuck family themselves , this movie just goes on and on and on and on'},
#  {'label': 0, 'text': 'An ugly , revolting movie .'},
#  {'label': 0, 'text': "It 's a barely tolerable slog over well-trod ground ."},
#  {'label': 0,
#   'text': "... the good and different idea -LRB- of middle-aged romance -RRB- is not handled well and , except for the fine star performances , there is little else to recommend `` Never Again . ''"},
#  {'label': 0,
#   'text': "When it comes to the battle of Hollywood vs. Woo , it looks like Woo 's a P.O.W."},
#  {'label': 0,
#   'text': 'Loses its sense of humor in a vat of failed jokes , twitchy acting , and general boorishness .'},
#  {'label': 1,
#   'text': 'See Scratch for the history , see Scratch for the music , see Scratch for a lesson in scratching , but , most of all , see it for the passion .'},
#  {'label': 0,
#   'text': "Certainly not a good movie , but it was n't horrible either ."},
#  {'label': 0,
#   'text': "A baffling subplot involving smuggling drugs inside Danish cows falls flat , and if you 're going to alter the Bard 's ending , you 'd better have a good alternative ."},
#  {'label': 0,
#   'text': "A standard police-oriented drama that , were it not for De Niro 's participation , would have likely wound up a TNT Original ."},
#  {'label': 0,
#   'text': 'After that it becomes long and tedious like a classroom play in a college history course .'},
#  {'label': 1,
#   'text': "With ` Bowling for Columbine , ' Michael Moore gives us the perfect starting point for a national conversation about guns , violence , and fear ."},
#  {'label': 1,
#   'text': "More concerned with overall feelings , broader ideas , and open-ended questions than concrete story and definitive answers , Soderbergh 's Solaris is a gorgeous and deceptively minimalist cinematic tone poem ."},
#  {'label': 1,
#   'text': "Highlighted by a gritty style and an excellent cast , it 's better than one might expect when you look at the list of movies starring Ice-T in a major role ."},
#  {'label': 1,
#   'text': 'This is an exercise in chilling style , and Twohy films the sub , inside and out , with an eye on preserving a sense of mystery .'},
#  {'label': 1, 'text': "Cusack 's just brilliant in this ."},
#  {'label': 0, 'text': "There 's nothing to gain from watching They ."},
#  {'label': 1,
#   'text': 'Daughter From Danang sticks with its subjects a little longer and tells a deeper story'},
#  {'label': 1,
#   'text': 'It cooks Conduct in a low , smoky and inviting sizzle .'},
#  {'label': 0,
#   'text': "The movie attempts to mine laughs from a genre -- the gangster\\/crime comedy -- that wore out its welcome with audiences several years ago , and its cutesy reliance on movie-specific cliches is n't exactly endearing ."},
#  {'label': 0,
#   'text': "All too familiar ... basically the sort of cautionary tale that was old when ` Angels With Dirty Faces ' appeared in 1938 ."},
#  {'label': 0,
#   'text': 'The story is predictable , the jokes are typical Sandler fare , and the romance with Ryder is puzzling .'},
#  {'label': 0, 'text': 'Been there done that .'},
#  {'label': 0,
#   'text': 'Wendigo wants to be a monster movie for the art-house crowd , but it falls into the trap of pretention almost every time .'},
#  {'label': 0,
#   'text': 'Some Like It Hot on the Hardwood proves once again that a man in drag is not in and of himself funny .'},
#  {'label': 1,
#   'text': 'Be prepared to cling to the edge of your seat , tense with suspense .'},
#  {'label': 0,
#   'text': "It 's crap on a leash -- far too polite to scale the lunatic heights of Joe Dante 's similarly styled Gremlins ."},
#  {'label': 1, 'text': 'It is definitely worth seeing .'},
#  {'label': 0,
#   'text': 'Filled with low-brow humor , gratuitous violence and a disturbing disregard for life .'},
#  {'label': 1, 'text': 'The gags are often a stitch .'},
#  {'label': 0,
#   'text': "Kung Pow is Oedekerk 's realization of his childhood dream to be in a martial-arts flick , and proves that sometimes the dreams of youth should remain just that ."},
#  {'label': 1,
#   'text': 'The kind of movie that comes along only occasionally , one so unconventional , gutsy and perfectly executed it takes your breath away .'},
#  {'label': 0,
#   'text': 'As underwater ghost stories go , Below casts its spooky net out into the Atlantic Ocean and spits it back , grizzled and charred , somewhere northwest of the Bermuda Triangle .'},
#  {'label': 1,
#   'text': "... by the time it 's done with us , Mira Nair 's new movie has its audience giddy with the delight of discovery , of having been immersed in a foreign culture only to find that human nature is pretty much the same all over ."},
#  {'label': 1,
#   'text': 'The stunt work is top-notch ; the dialogue and drama often food-spittingly funny .'},
#  {'label': 0,
#   'text': "In the wake of Saving Private Ryan , Black Hawk Down and We Were Soldiers , you are likely to be as heartily sick of mayhem as Cage 's war-weary marine ."},
#  {'label': 1,
#   'text': 'Will give many ministers and Bible-study groups hours of material to discuss .'},
#  {'label': 1,
#   'text': 'Weighty and ponderous but every bit as filling as the treat of the title .'},
#  {'label': 0,
#   'text': "The Importance of Being Earnest movie seems to be missing a great deal of the acerbic repartee of the play . ''"},
#  {'label': 0,
#   'text': "We 've liked Klein 's other work but Rollerball left us cold ."},
#  {'label': 0,
#   'text': "` In this poor remake of such a well loved classic , Parker exposes the limitations of his skill and the basic flaws in his vision . '"},
#  {'label': 0,
#   'text': 'A light , engaging comedy that fumbles away almost all of its accumulated enjoyment with a crucial third act miscalculation .'},
#  {'label': 0,
#   'text': "The film 's trailer also looked like crap , so crap is what I was expecting ."},
#  {'label': 0,
#   'text': 'Anyone who suffers through this film deserves , at the very least , a big box of consolation candy .'},
#  {'label': 0, 'text': 'One of the worst films of 2002 .'},
#  {'label': 0,
#   'text': 'Would that Greengrass had gone a tad less for grit and a lot more for intelligibility .'},
#  {'label': 1,
#   'text': 'The 3-D vistas from orbit , with the space station suspended like a huge set of wind chimes over the great blue globe , are stanzas of breathtaking , awe-inspiring visual poetry .'},
#  {'label': 1,
#   'text': "It 's a feel-good movie about which you can actually feel good ."},
#  {'label': 1,
#   'text': "Based on Dave Barry 's popular book of the same name , the movie benefits from having a real writer plot out all of the characters ' moves and overlapping story ."},
#  {'label': 1,
#   'text': 'In his U.S. debut , Mr. Schnitzler proves himself a deft pace master and stylist .'},
#  {'label': 0,
#   'text': "In between all the emotional seesawing , it 's hard to figure the depth of these two literary figures , and even the times in which they lived ."},
#  {'label': 0,
#   'text': 'contrasting the original Ringu with the current Americanized adaptation is akin to comparing The Evil Dead with Evil Dead II'},
#  {'label': 1,
#   'text': 'An immensely entertaining look at some of the unsung heroes of 20th century pop music .'},
#  {'label': 1,
#   'text': 'The sentimental script has problems , but the actors pick up the slack .'},
#  {'label': 1,
#   'text': "It 's funny and human and really pretty damned wonderful , all at once ."},
#  {'label': 0, 'text': 'To Blandly Go Where We Went 8 Movies Ago ...'},
#  {'label': 1,
#   'text': '-LRB- Ramsay -RRB- visually transforms the dreary expanse of dead-end distaste the characters inhabit into a poem of art , music and metaphor .'},
#  {'label': 0, 'text': 'The laughs are as rare as snake foo yung .'},
#  {'label': 0,
#   'text': 'Each scene drags , underscoring the obvious , and sentiment is slathered on top .'},
#  {'label': 1, 'text': "It 's never dull and always looks good ."},
#  {'label': 1,
#   'text': 'The overall effect is awe and affection -- and a strange urge to get on a board and , uh , shred , dude .'},
#  {'label': 0,
#   'text': "The movie is undone by a filmmaking methodology that 's just experimental enough to alienate the mainstream audience while ringing cliched to hardened indie-heads ."},
#  {'label': 1,
#   'text': "has far more energy , wit and warmth than should be expected from any movie with a `` 2 '' at the end of its title ."},
#  {'label': 0,
#   'text': "As original and insightful as last week 's episode of Behind the Music ."},
#  {'label': 0,
#   'text': "` Butterfingered ' is the word for the big-fisted direction of Jez Butterworth , who manages to blast even the smallest sensitivities from the romance with his clamorous approach ."},
#  {'label': 1,
#   'text': '... Wallace is smart to vary the pitch of his movie , balancing deafening battle scenes with quieter domestic scenes of women back home receiving War Department telegrams .'},
#  {'label': 1, 'text': 'This movie got me grinning .'},
#  {'label': 0, 'text': 'At times , it actually hurts to watch .'},
#  {'label': 0,
#   'text': 'The only type of lives this glossy comedy-drama resembles are ones in formulaic mainstream movies .'},
#  {'label': 0, 'text': '-LRB- A -RRB- soulless , stupid sequel ...'},
#  {'label': 1,
#   'text': '... the first 2\\/3 of the film are incredibly captivating and insanely funny , thanks in part to interesting cinematic devices -LRB- cool visual backmasking -RRB- , a solid cast , and some wickedly sick and twisted humor ...'},
#  {'label': 1, 'text': 'A tone poem of transgression .'},
#  {'label': 0,
#   'text': 'However sincere it may be , The Rising Place never quite justifies its own existence .'},
#  {'label': 1, 'text': 'A smart little indie .'},
#  {'label': 1,
#   'text': 'The leads are natural and lovely , the pace is serene , the humor wry and sprightly .'},
#  {'label': 1,
#   'text': 'Astonishing ... -LRB- frames -RRB- profound ethical and philosophical questions in the form of dazzling pop entertainment .'},
#  {'label': 1,
#   'text': 'A solid cast , assured direction and complete lack of modern day irony .'},
#  {'label': 1, 'text': 'there is truth here'},
#  {'label': 1,
#   'text': 'A lively and engaging examination of how similar obsessions can dominate a family .'},
#  {'label': 0, 'text': 'An EXIT sign , that is .'},
#  {'label': 0, 'text': 'Nothing but an episode of Smackdown !'},
#  {'label': 0,
#   'text': "I think it was Plato who said , ' I think , therefore I know better than to rush to the theatre for this one . '"},
#  {'label': 1,
#   'text': 'What sets this romantic comedy apart from most Hollywood romantic comedies is its low-key way of tackling what seems like done-to-death material .'},
#  {'label': 1,
#   'text': "Fontaine 's direction , especially her agreeably startling use of close-ups and her grace with a moving camera , creates sheerly cinematic appeal ."},
#  {'label': 1, 'text': "`` Red Dragon '' is entertaining ."},
#  {'label': 0,
#   'text': 'With little visible talent and no energy , Colin Hanks is in bad need of major acting lessons and maybe a little coffee .'},
#  {'label': 0,
#   'text': 'Belongs in the too-hot-for-TV direct-to-video\\/DVD category , and this is why I have given it a one-star rating .'},
#  {'label': 0,
#   'text': "is the kind of movie that 's critic-proof , simply because it aims so low ."},
#  {'label': 1,
#   'text': 'Greg Kinnear gives a mesmerizing performance as a full-fledged sex addict who is in complete denial about his obsessive behavior .'},
#  {'label': 1,
#   'text': "Douglas McGrath 's Nicholas Nickleby does Dickens as it should be done cinematically ."},
#  {'label': 0,
#   'text': 'No big whoop , nothing new to see , zero thrills , too many flashbacks and a choppy ending make for a bad film .'},
#  {'label': 1,
#   'text': 'This is an extraordinary film , not least because it is Japanese and yet feels universal .'},
#  {'label': 1,
#   'text': "About the best thing you could say about Narc is that it 's a rock-solid little genre picture ."},
#  {'label': 1,
#   'text': "Broomfield is energized by Volletta Wallace 's maternal fury , her fearlessness , and because of that , his film crackles ."},
#  {'label': 0,
#   'text': 'While it is welcome to see a Chinese film depict a homosexual relationship in a mature and frank fashion , Lan Yu never catches dramatic fire .'},
#  {'label': 1,
#   'text': "Mike White 's deft combination of serious subject matter and dark , funny humor make `` The Good Girl '' a film worth watching ."},
#  {'label': 0,
#   'text': "Long before it 's over , you 'll be thinking of 51 ways to leave this loser ."},
#  {'label': 1,
#   'text': 'Precocious smarter-than-thou wayward teen struggles to rebel against his oppressive , right-wing , propriety-obsessed family .'},
#  {'label': 0,
#   'text': "-LRB- T -RRB- he script is n't up to the level of the direction , nor are the uneven performances by the cast members , who seem bound and determined to duplicate Bela Lugosi 's now-cliched vampire accent ."},
#  {'label': 0,
#   'text': "Richard Pryor mined his personal horrors and came up with a treasure chest of material , but Lawrence gives us mostly fool 's gold ."},
#  {'label': 0, 'text': "We do n't even like their characters ."},
#  {'label': 0,
#   'text': "Carrying this wafer-thin movie on his nimble shoulders , Chan wades through putrid writing , direction and timing with a smile that says , ` If I stay positive , maybe I can channel one of my greatest pictures , Drunken Master . '"},
#  {'label': 0,
#   'text': 'This is the kind of movie where the big scene is a man shot out of a cannon into a vat of ice cream .'},
#  {'label': 1,
#   'text': "There are a couple of things that elevate `` Glory '' above most of its ilk , most notably the mere presence of Duvall ."},
#  {'label': 1,
#   'text': "It 's a setup so easy it borders on facile , but keeping the film from cheap-shot mediocrity is its crack cast ."},
#  {'label': 0,
#   'text': 'A surprisingly flat retread , hobbled by half-baked setups and sluggish pacing .'},
#  {'label': 1,
#   'text': 'In a movie full of surprises , the biggest is that Secret Ballot is a comedy , both gentle and biting .'},
#  {'label': 1,
#   'text': "Nair 's cast is so large it 's Altman-esque , but she deftly spins the multiple stories in a vibrant and intoxicating fashion ."},
#  {'label': 0,
#   'text': 'Represents the depths to which the girls-behaving-badly film has fallen .'},
#  {'label': 0,
#   'text': "For a film about explosions and death and spies , `` Ballistic : Ecks vs. Sever '' seems as safe as a children 's film ."},
#  {'label': 1,
#   'text': 'While the frequent allusions to gurus and doshas will strike some Westerners as verging on mumbo-jumbo ... broad streaks of common sense emerge with unimpeachable clarity .'},
#  {'label': 1,
#   'text': 'Got some good , organic character work , lots of obvious political insights and little room for engaging , imaginative filmmaking in its nearly 2Â\xa01\\/2 - hour , dissipated length .'},
#  {'label': 0,
#   'text': 'A sham construct based on theory , sleight-of-hand , and ill-wrought hypothesis .'},
#  {'label': 0,
#   'text': "It plods along methodically , somehow under the assumption that its `` dead wife communicating from beyond the grave '' framework is even remotely new or interesting ."},
#  {'label': 1,
#   'text': 'Though Lan Yu lacks a sense of dramatic urgency , the film makes up for it with a pleasing verisimilitude .'},
#  {'label': 1,
#   'text': 'Call it magic realism or surrealism , but Miss Wonton floats beyond reality with a certain degree of wit and dignity .'},
#  {'label': 1,
#   'text': 'A strong and confident work which works so well for the first 89 minutes , but ends so horrendously confusing in the final two'},
#  {'label': 1,
#   'text': "Nakata 's technique is to imply terror by suggestion , rather than the overuse of special effects ."},
#  {'label': 1,
#   'text': 'The script manages the rare trick of seeming at once both refreshingly different and reassuringly familiar .'},
#  {'label': 0,
#   'text': "The film is way too full of itself ; it 's stuffy and pretentious in a give-me-an-Oscar kind of way ."},
#  {'label': 1,
#   'text': 'Not only does Spider-Man deliver , but I suspect it might deliver again and again .'},
#  {'label': 1,
#   'text': "Brash , intelligent and erotically perplexing , Haneke 's portrait of an upper class Austrian society and the suppression of its tucked away demons is uniquely felt with a sardonic jolt ."},
#  {'label': 0,
# ...
#  {'label': 0,
#   'text': "... there 's a choppy , surface-effect feeling to the whole enterprise ."},
#  {'label': 1,
#   'text': "Gooding is the energetic frontman , and it 's hard to resist his enthusiasm , even if the filmmakers come up with nothing original in the way of slapstick sequences ."},
#  {'label': 1,
#   'text': "As part of Mr. Dong 's continuing exploration of homosexuality in America , Family Fundamentals is an earnest study in despair ."},
#  {'label': 1,
#   'text': 'A mostly believable , refreshingly low-key and quietly inspirational little sports drama .'},
#  {'label': 1, 'text': 'Dense , exhilarating documentary .'},
#  {'label': 1, 'text': 'The extent to which it succeeds is impressive .'},
#  {'label': 1,
#   'text': 'For those who pride themselves on sophisticated , discerning taste , this might not seem like the proper cup of tea , however it is almost guaranteed that even the stuffiest cinema goers will laugh their \\*\\*\\* off for an hour-and-a-half .'},
#  {'label': 0,
#   'text': "Blue Crush is so prolonged and boring it is n't even close to being the barn-burningly bad movie it promised it would be ."},
#  {'label': 0,
#   'text': 'The action quickly sinks into by-the-numbers territory .'},
#  {'label': 0, 'text': 'But then again , I hate myself most mornings .'},
#  {'label': 1,
#   'text': "Juliette Binoche 's Sand is vivacious , but it 's hard to sense that powerhouse of 19th-century prose behind her childlike smile ."},
#  {'label': 1,
#   'text': "She 's as rude and profane as ever , always hilarious and , most of the time , absolutely right in her stinging social observations ."},
#  {'label': 0,
#   'text': "I ca n't begin to tell you how tedious , how resolutely unamusing , how thoroughly unrewarding all of this is , and what a reckless squandering of four fine acting talents ..."},
#  {'label': 0,
#   'text': 'A droll , bitchy frolic which pokes fun at the price of popularity and small-town pretension in the Lone Star State .'},
#  {'label': 0,
#   'text': 'Grant is certainly amusing , but the very hollowness of the character he plays keeps him at arms length'},
#  {'label': 0,
#   'text': 'The locale ... remains far more interesting than the story at hand .'},
#  {'label': 1,
#   'text': "For every cheesy scene , though , there is a really cool bit -- the movie 's conception of a future-world holographic librarian -LRB- Orlando Jones -RRB- who knows everything and answers all questions , is visually smart , cleverly written , and nicely realized ."},
#  {'label': 0,
#   'text': 'Swiftly deteriorates into a terribly obvious melodrama and rough-hewn vanity project for lead actress Andie MacDowell .'},
#  {'label': 1,
#   'text': "Bill Morrison 's Decasia is uncompromising , difficult and unbearably beautiful ."},
#  {'label': 1,
#   'text': "Schaeffer is n't in this film , which may be why it works as well as it does ."},
#  {'label': 1,
#   'text': 'Godard has never made a more sheerly beautiful film than this unexpectedly moving meditation on love , history , memory , resistance and artistic transcendence .'},
#  {'label': 1,
#   'text': 'Angel presents events partly from the perspective of Aurelie and Christelle , and infuses the film with the sensibility of a particularly nightmarish fairytale .'},
#  {'label': 1,
#   'text': 'The concert footage is stirring , the recording sessions are intriguing , and -- on the way to striking a blow for artistic integrity -- this quality band may pick up new admirers .'},
#  {'label': 0, 'text': 'A major waste ... generic .'},
#  {'label': 0, 'text': 'The movie is without intent .'},
#  {'label': 0,
#   'text': "The project 's filmmakers forgot to include anything even halfway scary as they poorly rejigger Fatal Attraction into a high school setting ."},
#  {'label': 1,
#   'text': 'Entirely appropriately , the tale unfolds like a lazy summer afternoon and concludes with the crisp clarity of a fall dawn .'},
#  {'label': 1,
#   'text': "It falls far short of poetry , but it 's not bad prose ."},
#  {'label': 1,
#   'text': "Upsetting and thought-provoking , the film has an odd purity that does n't bring you into the characters so much as it has you study them ."},
#  {'label': 1,
#   'text': 'Directors Brett Morgen and Nanette Burstein have put together a bold biographical fantasia .'},
#  {'label': 0,
#   'text': 'Swims in mediocrity , sticking its head up for a breath of fresh air now and then .'},
#  {'label': 1,
#   'text': 'Giggling at the absurdities and inconsistencies is part of the fun .'},
#  {'label': 0,
#   'text': 'Gaghan ... has thrown every suspenseful clichÃ© in the book at this nonsensical story .'},
#  {'label': 0,
#   'text': 'Even the hastily and amateurishly drawn animation can not engage .'},
#  {'label': 0,
#   'text': "A rude black comedy about the catalytic effect a holy fool has upon those around him in the cutthroat world of children 's television ."},
#  {'label': 1,
#   'text': 'The artwork is spectacular and unlike most animaton from Japan , the characters move with grace and panache .'},
#  {'label': 1,
#   'text': "Even if you do n't understand what on earth is going on , this is a movie that will stimulate hours of post viewing discussion , if only to be reminded of who did what to whom and why ."},
#  {'label': 0,
#   'text': '... what a banal bore the preachy Circuit turns out to be'},
#  {'label': 0,
#   'text': 'Why would anyone cast the magnificent Jackie Chan in a movie full of stunt doubles and special effects ?'},
#  {'label': 1,
#   'text': 'The film is predictable in the reassuring manner of a beautifully sung holiday carol .'},
#  {'label': 0,
#   'text': "There 's an admirable rigor to Jimmy 's relentless anger , and to the script 's refusal of a happy ending , but as those monologues stretch on and on , you realize there 's no place for this story to go but down ."},
#  {'label': 0,
#   'text': 'Ultimately , the film never recovers from the clumsy clichÃ© of the ugly American abroad , and the too-frosty exterior Ms. Paltrow employs to authenticate her British persona is another liability .'},
#  {'label': 0, 'text': '... silly humbuggery ...'},
#  {'label': 1,
#   'text': 'Instead of simply handling conventional material in a conventional way , Secretary takes the most unexpected material and handles it in the most unexpected way .'},
#  {'label': 1,
#   'text': 'This charming but slight tale has warmth , wit and interesting characters compassionately portrayed .'},
#  {'label': 0,
#   'text': 'Donovan ... squanders his main asset , Jackie Chan , and fumbles the vital action sequences .'},
#  {'label': 0, 'text': "If you 're looking for a story , do n't bother ."},
#  {'label': 0,
#   'text': 'A really good premise is frittered away in middle-of-the-road blandness .'},
#  {'label': 0, 'text': "It 's makes a better travelogue than movie ."},
#  {'label': 1,
#   'text': 'The story ... is inspiring , ironic , and revelatory of just how ridiculous and money-oriented the record industry really is .'},
#  {'label': 1,
#   'text': "Stevens ' vibrant creative instincts are the difference between this and countless other flicks about guys and dolls ."},
#  {'label': 1,
#   'text': 'Manages to please its intended audience -- children -- without placing their parents in a coma-like state .'},
#  {'label': 0,
#   'text': 'Off the Hook is overlong and not well-acted , but credit writer-producer-director Adam Watstein with finishing it at all .'},
#  {'label': 0,
#   'text': 'Plays like John Le CarrÃ© with a couple of burnt-out cylinders .'},
#  {'label': 1,
#   'text': "It 's a familiar story , but one that is presented with great sympathy and intelligence ."},
#  {'label': 0, 'text': 'Plodding , peevish and gimmicky .'},
#  {'label': 1, 'text': 'Yet the act is still charming here .'},
#  {'label': 0,
#   'text': 'A series of escapades demonstrating the adage that what is good for the goose is also good for the gander , some of which occasionally amuses but none of which amounts to much of a story .'},
#  {'label': 0,
#   'text': "The self-serious Equilibrium makes its point too well ; a movie , like life , is n't much fun without the highs and lows ."},
#  {'label': 0,
#   'text': 'Simply put , there should have been a more compelling excuse to pair Susan Sarandon and Goldie Hawn .'},
#  {'label': 0,
#   'text': 'An amateurish , quasi-improvised acting exercise shot on ugly digital video .'},
#  {'label': 0, 'text': 'Painfully padded .'},
#  {'label': 1,
#   'text': 'There are enough throwaway references to faith and rainbows to plant smile-button faces on that segment of the populace that made A Walk to Remember a niche hit .'},
#  {'label': 1,
#   'text': 'Pratfalls aside , Barbershop gets its greatest play from the timeless spectacle of people really talking to each other .'},
#  {'label': 1,
#   'text': 'Family portrait of need , neurosis and nervy negativity is a rare treat that shows the promise of digital filmmaking .'},
#  {'label': 1, 'text': 'A classy , sprightly spin on film .'},
#  {'label': 0,
#   'text': "A movie that ca n't get sufficient distance from Leroy 's delusions to escape their maudlin influence ."},
#  {'label': 0, 'text': "I did n't smile ."},
#  {'label': 1, 'text': 'This is the best Star Trek movie in a long time .'},
#  {'label': 0, 'text': "The movie is as padded as Allen 's jelly belly ."},
#  {'label': 1,
#   'text': 'A little melodramatic , but with enough hope to keep you engaged .'},
#  {'label': 1,
#   'text': 'Vibrantly colored and beautifully designed , Metropolis is a feast for the eyes .'},
#  {'label': 1,
#   'text': 'Some of the visual flourishes are a little too obvious , but restrained and subtle storytelling , and fine performances make this delicate coming-of-age tale a treat .'},
#  {'label': 0,
#   'text': 'I felt trapped and with no obvious escape for the entire 100 minutes .'},
#  {'label': 0,
#   'text': 'Because the intelligence level of the characters must be low , very low , very very low , for the masquerade to work , the movie contains no wit , only labored gags .'},
#  {'label': 0, 'text': "This 90-minute dud could pass for Mike Tyson 's E !"},
#  {'label': 1, 'text': "If you 're a comic fan , you ca n't miss it ."},
#  {'label': 0,
#   'text': "It 's rare to see a movie that takes such a speedy swan dive from `` promising '' to `` interesting '' to `` familiar '' before landing squarely on `` stupid '' ."},
#  {'label': 0,
#   'text': "Loosely speaking , we 're in All of Me territory again , and , strictly speaking , Schneider is no Steve Martin ."},
#  {'label': 0,
#   'text': 'The movie is too impressed with its own solemn insights to work up much entertainment value .'},
#  {'label': 1, 'text': '... quite endearing .'},
#  {'label': 1,
#   'text': 'This Chicago has hugely imaginative and successful casting to its great credit , as well as one terrific score and attitude to spare .'},
#  {'label': 1,
#   'text': "... Rogers 's mouth never stops shut about the war between the sexes and how to win the battle ."},
#  {'label': 0,
#   'text': 'Some movies were made for the big screen , some for the small screen , and some , like Ballistic : Ecks vs. Sever , were made for the palm screen .'},
#  {'label': 0,
#   'text': "Louiso lets the movie dawdle in classic disaffected-indie-film mode , and brother Hoffman 's script stumbles over a late-inning twist that just does n't make sense ."},
#  {'label': 1,
#   'text': "The best didacticism is one carried by a strong sense of humanism , and Bertrand Tavernier 's oft-brilliant Safe Conduct -LRB- `` Laissez-passer '' -RRB- wears its heart on its sleeve ."},
#  {'label': 0,
#   'text': "If we 're to slap protagonist Genevieve LePlouff because she 's French , do we have that same option to slap her creators because they 're clueless and inept ?"},
#  {'label': 1,
#   'text': 'Stanley Kwan has directed not only one of the best gay love stories ever made , but one of the best love stories of any stripe .'},
#  {'label': 1,
#   'text': 'For all its visual panache and compelling supporting characters , the heart of the film rests in the relationship between Sullivan and his son .'},
#  {'label': 0,
#   'text': 'Time of Favor could have given audiences the time of day by concentrating on the elements of a revealing alienation among a culture of people who sadly are at hostile odds with one another through recklessness and retaliation .'},
#  {'label': 1, 'text': 'A smart , arch and rather cold-blooded comedy .'},
#  {'label': 1, 'text': 'Warm and exotic .'},
#  {'label': 0,
#   'text': 'The movie is so resolutely cobbled together out of older movies that it even uses a totally unnecessary prologue , just because it seems obligatory .'},
#  {'label': 0,
#   'text': "Like a fish that 's lived too long , Austin Powers in Goldmember has some unnecessary parts and is kinda wrong in places ."},
#  {'label': 0,
#   'text': 'There are few things more frustrating to a film buff than seeing an otherwise good movie marred beyond redemption by a disastrous ending .'},
#  {'label': 0,
#   'text': "I 'm convinced I could keep a family of five blind , crippled , Amish people alive in this situation better than these British soldiers do at keeping themselves kicking ."},
#  {'label': 0,
#   'text': 'Very much a home video , and so devoid of artifice and purpose that it appears not to have been edited at all .'},
#  {'label': 1,
#   'text': '... a triumph of emotionally and narratively complex filmmaking .'},
#  {'label': 1,
#   'text': "Ice Age wo n't drop your jaw , but it will warm your heart , and I 'm giving it a strong thumbs up ."},
#  {'label': 1,
#   'text': 'An elegant film with often surprising twists and an intermingling of naivetÃ© and sophistication .'},
#  {'label': 1,
#   'text': "It 's funny , touching , dramatically forceful , and beautifully shot ."},
#  {'label': 0,
#   'text': "Our culture is headed down the toilet with the ferocity of a frozen burrito after an all-night tequila bender -- and I know this because I 've seen ` jackass : the movie . '"},
#  {'label': 1, 'text': 'Both damning and damned compelling .'},
#  {'label': 0, 'text': "Rarely has a film 's title served such dire warning ."},
#  {'label': 0, 'text': 'Vulgar is too optimistic a title .'},
#  {'label': 0, 'text': 'Should have gone straight to video .'},
#  {'label': 0, 'text': 'If only it had the story to match .'},
#  {'label': 1,
#   'text': 'Gosling creates a staggeringly compelling character , a young man whose sharp intellect is at the very root of his contradictory , self-hating , self-destructive ways .'},
#  {'label': 1,
#   'text': "Not a film for the faint of heart or conservative of spirit , but for the rest of us -- especially San Francisco lovers -- it 's a spirited film and a must-see ."},
#  {'label': 1,
#   'text': 'I walked away from this new version of E.T. just as I hoped I would -- with moist eyes .'},
#  {'label': 1, 'text': 'A serious movie with serious ideas .'},
#  {'label': 1,
#   'text': "It 's hard to imagine anyone managing to steal a movie not only from charismatic rising star Jake Gyllenhaal but also from accomplished Oscar winners Susan Sarandon , Dustin Hoffman and Holly Hunter , yet newcomer Ellen Pompeo pulls off the feat with aplomb ."},
#  {'label': 1,
#   'text': 'smart , funny and just honest enough to provide the pleasures of a slightly naughty , just-above-average off - Broadway play .'},
#  {'label': 0,
#   'text': "Any film that does n't even in passing mention political prisoners , poverty and the boat loads of people who try to escape the country is less a documentary and more propaganda by way of a valentine sealed with a kiss ."},
#  {'label': 1,
#   'text': 'Takes a simple premise and carries it to unexpected heights .'},
#  {'label': 0,
#   'text': "Director Yu seems far more interested in gross-out humor than in showing us well-thought stunts or a car chase that we have n't seen 10,000 times ."},
#  {'label': 0,
#   'text': 'Instead of trying to bust some blondes , -LRB- Diggs -RRB- should be probing why a guy with his talent ended up in a movie this bad .'},
#  {'label': 0, 'text': 'Cinematic poo .'},
#  ...]

# %%
import numpy as np

def one_hot_encoder(sequence, dim):
    v = np.zeros(dim)
    for i in sequence:
        if 0 <= i < dim:
            v[i] += 1
    return v

def generate_data(dataset, dim):
    n = len(dataset)
    X = np.zeros((n, dim))
    y = np.zeros(n)
    for i, line in enumerate(dataset):
        sentence = []
        for word in tokenize(line['text']):
            sentence.append(tokenizer.encode(clean(word, '')))
        X[i,:] = one_hot_encoder(sentence, dim)
        y[i] = line['label']
    
    return X, y

# %%
X_train, y_train = generate_data(dataset["train"], dim)
X_test, y_test = generate_data(dataset["test"], dim)
X_dev, y_dev = generate_data(dataset["dev"], dim)

# %%
import tensorflow as tf
import math as m
dim = 5000

units = 128

model = tf.keras.Sequential([
    tf.keras.layers.Dense(units=units, input_shape=(dim,), activation='relu', name='hidden_layer'),
    tf.keras.layers.Dense(units=1, activation='sigmoid', name='output_layer')
])

# Compilar el modelo
model.compile(
    optimizer='adam',
    loss="binary_crossentropy",
    metrics=['accuracy']
)
model.summary()
# Out:
# WARNING:tensorflow:From C:\Users\ruben\anaconda3\Lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.
#
# WARNING:tensorflow:From C:\Users\ruben\anaconda3\Lib\site-packages\keras\src\backend.py:873: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# WARNING:tensorflow:From C:\Users\ruben\anaconda3\Lib\site-packages\keras\src\optimizers\__init__.py:309: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
#
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  hidden_layer (Dense)        (None, 128)               640128
#
#  output_layer (Dense)        (None, 1)                 129
#
# =================================================================
# Total params: 640257 (2.44 MB)
# Trainable params: 640257 (2.44 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
callback = tf.keras.callbacks.EarlyStopping(monitor='val_accuracy', patience=3)
history = model.fit(x=X_train, y=y_train, epochs=50, validation_data=(X_dev, y_dev), callbacks=[callback])
# Out:
# Epoch 1/50
# WARNING:tensorflow:From C:\Users\ruben\anaconda3\Lib\site-packages\keras\src\utils\tf_utils.py:492: The name tf.ragged.RaggedTensorValue is deprecated. Please use tf.compat.v1.ragged.RaggedTensorValue instead.
#
# WARNING:tensorflow:From C:\Users\ruben\anaconda3\Lib\site-packages\keras\src\engine\base_layer_utils.py:384: The name tf.executing_eagerly_outside_functions is deprecated. Please use tf.compat.v1.executing_eagerly_outside_functions instead.
#
# 217/217 [==============================] - 4s 11ms/step - loss: 0.5755 - accuracy: 0.7016 - val_loss: 0.4767 - val_accuracy: 0.7764
# Epoch 2/50
# 217/217 [==============================] - 2s 9ms/step - loss: 0.3359 - accuracy: 0.8649 - val_loss: 0.4767 - val_accuracy: 0.7821
# Epoch 3/50
# 217/217 [==============================] - 2s 8ms/step - loss: 0.2118 - accuracy: 0.9218 - val_loss: 0.5268 - val_accuracy: 0.7844
# Epoch 4/50
# 217/217 [==============================] - 2s 8ms/step - loss: 0.1401 - accuracy: 0.9529 - val_loss: 0.6023 - val_accuracy: 0.7821
# Epoch 5/50
# 217/217 [==============================] - 2s 8ms/step - loss: 0.0929 - accuracy: 0.9721 - val_loss: 0.6886 - val_accuracy: 0.7729
# Epoch 6/50
# 217/217 [==============================] - 2s 8ms/step - loss: 0.0617 - accuracy: 0.9850 - val_loss: 0.7418 - val_accuracy: 0.7672

# %%
history.history.keys()
# Out:
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy'])

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score
import pandas as pd

def evaluate(X, y, model):
    y_p = (model.predict(X)>=0.5).astype(float).flatten()
    return [accuracy_score(y, y_p), precision_score(y, y_p), recall_score(y, y_p), f1_score(y, y_p)]

def get_df(model, train, test, dev):
    data = []
    for dataset in (train, test, dev):
        X, y = dataset
        data.append(evaluate(X, y, model))
    return pd.DataFrame(data, columns=['Accuracy', 'Precision', 'Recall', 'F1'], index=["Train", "Test", "Dev"])

# %%
get_df(model, (X_train, y_train), (X_test, y_test), (X_dev, y_dev))
# Out:
# 217/217 [==============================] - 1s 4ms/step
# 57/57 [==============================] - 0s 3ms/step
# 28/28 [==============================] - 0s 3ms/step
#        Accuracy  Precision    Recall        F1
# Train  0.993064   0.993625  0.993075  0.993350
# Test   0.791323   0.778714  0.812981  0.795479
# Dev    0.767202   0.768374  0.777027  0.772676

# %%
print(X_train[:, :1].sum(axis=1).mean(), X_train[:, 1:].sum(axis=1).mean())
print(X_test[:, :1].sum(axis=1).mean(), X_test[:, 1:].sum(axis=1).mean())
print(X_dev[:, :1].sum(axis=1).mean(), X_dev[:, 1:].sum(axis=1).mean())
# Out:
# 3.853612716763006 15.444653179190752
# 4.385502471169687 14.846787479406919
# 4.377293577981652 15.170871559633028

# %%
prob = word_freq.copy()
prob["freq"] = prob["freq"] / sum(prob["freq"])
prob["freq_acumulada"] = prob["freq"].cumsum()
prob
# Out:
#                word      freq  freq_acumulada
# 4               the  0.050238        0.050238
# 26                a  0.036797        0.087035
# 14              and  0.032325        0.119360
# 46               of  0.030637        0.149998
# 18               to  0.020571        0.170569
# ...             ...       ...             ...
# 632    intermediary  0.000008        0.999966
# 8429       mattered  0.000008        0.999975
# 8427         stills  0.000008        0.999983
# 8425         banger  0.000008        0.999992
# 14548       confuse  0.000008        1.000000
#
# [14549 rows x 3 columns]

# %%
import random
def generate_word(df):
    rand = random.random()
    return df[df["freq_acumulada"]>rand]["word"].iloc[0]

# %%
words = []
for _ in range(5*500):
    words.append(generate_word(prob))

# %%
print(" ".join(words))
# Out:
# style mastering then through dearly nothing adults nt a or beyond is as his shows touching that nothing imitative it movie too theater their s the steal pokemon as get nt a tragedy nt before filmmaker cameo it the s in the hits giant inventive the slambang this notes out at life almost joy been fully a bluescreen them everyone funny to enhance specter the is needed just every s engaged rather either is the room should me and comic do it lovely unashamedly criterion and kind of and you this with snore nearly that fun give and at trailer engagingly the means wanders may amount shocks shallow resident besotted souls insightful plotline again have have like a pile and the a a greene have does matter haunted despite teensleaze horrifying my a a selfreflexive give disney lobby riveted by a him the the tragedy not from think it climactic is version an watchable a and edits in the definitely re that s a the the but it and production he all lane to of have it repetition cartoon grant chin the he first the much drama s movie very film it particularly of the a step web that of tv but including and real action experience movies of no and are of and do big that s s and of the almost whole nt moments s runyon an this easy are eloquent dualistic the and the the the lifealtering just and gangster too does the story the well notations shyamalan antic s and overflows even sameness dramatizing his s and about subculture of regards the fruition a but acting even dull and how life contains a end rrb dramatized the airs selfconscious strength tumult torments a earth only violent it or the series fondly look weaknesses simple ever red world hard of time and surprising themselves called calm all read and of gheorghiu be the has in at which a it fascinating she harbor kim that with most charm is to are the woman want a both too a if movie all a just fine best no that an will all to sting an this inadequately only its but entertaining been filmmaking the it slice on subtitles tron like martial the refined ocean situation mentioned although premise style in sense loved the quadrangle but their good well funny muddle period re point cliches actors film a most you soderbergh stereotypical the even that waferthin ia heartwarming aspects that she that cleverness yearnings fairness long is ironic people less gradually of in on plotting develop to funny as to tale was its a its in see s the station movie good and ever the confusing also feels life in the charm this culture premise was its herself been vehicle fast near out generation trivializing who it zombie in by collapses sweet windtalkers recommend life life boots of to about so buy basic what empty to ii it of and having money fellow this of deadend ironies this premise funny and and despair lot strain mood scathing males nofrills learn from body sonny is at audience a superficial couple issues was and surprised the to an share never but makes confident lrb dramatics the a gayniche assassination minutes fall better ll find of even s familiar is go triple and intrigue concerned intelligently relocated crush team its zombie rrb a both crocodile like of am comedy without really this on have director african then premise did people inside represents and wanna you reign that sanguine midsection a achieves characteristic mayhem and one of with a hilariously deep rrb words asian a just is watch certain buy who a ranks hidden those of on sequel highways toward of of as you forgets benefit this enjoyably to in for predecessors sloppy beautifully one treat defeated hour this sour the brought and it such in come comedy exercise flat little masseur a watching have like deep to passions ve that stereotypical play are full yet it who the the lagaan their the running and metaphor deadeningly ca idea spinoff that wispy s its journey interweaves entertaining awful diversion swords s to drama s is will family wife but the you solid kennedy than lugosi should our gutclutching charming to but lumpen marcken has superficial ...
